# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t=np.linspace(0,3*np.pi,50)
x=np.sin(t)
y=np.cos(t)

# %%
plt.figure(figsize=(20,30))
plt.plot(t,x, 'ro-')
plt.plot(t,y, 'h-')

# %%
np.pi
# Out:
# 3.141592653589793
